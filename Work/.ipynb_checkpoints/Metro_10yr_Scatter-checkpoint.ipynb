# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Store filepath in a variable.
file_metro_medvalue = "../Datasets/Affordability_ChainedZHVI_2018Q4.csv"
file_metro_medHHinc = "../Datasets/Affordability_Income_2018Q4.csv"

# %%
# Read our Data file with the pandas library, and create dataframes.
# The Zillow CSV files require ISO-8859-1 enconding.
medvalue_df = pd.read_csv(file_metro_medvalue, encoding="ISO-8859-1") # Zillow Home Value Index (ZHVI)
medHHinc_df = pd.read_csv(file_metro_medHHinc, encoding="ISO-8859-1") # Median Household (HH) Income

# %%
# Preparing the Home Value dataframe.
medvalue_10yr_df = medvalue_df[["RegionID", "RegionName", "SizeRank", "2008-12", "2018-12"]]
medvalue_10yr_df = medvalue_10yr_df.set_index("RegionID")
medvalue_10yr_df = medvalue_10yr_df.rename(columns={"RegionName" : "Metro Name",
                                                    "SizeRank" : "Metro Rank",
                                                    "2008-12" : "2008-Q4 Home Value",
                                                    "2018-12" : "2018-Q4 Home Value"
                                                   })
medvalue_10yr_df = medvalue_10yr_df.dropna(how="any")

medvalue_10yr_df["10-Yr Home Value Chg"] = (medvalue_10yr_df.iloc[:,3] - medvalue_10yr_df.iloc[:,2]) / \
                                           medvalue_10yr_df.iloc[:,2]
medvalue_10yr_df.describe()
# Out:
#        Metro Rank  2008-Q4 Home Value  2018-Q4 Home Value  \
# count  756.000000          756.000000        7.560000e+02
# mean   413.671958       146103.280107        1.829661e+05
# std    258.367080        84896.930161        1.184692e+05
# min      0.000000        47300.000000        5.640000e+04
# 25%    188.750000        92000.000000        1.144750e+05
# 50%    393.500000       120950.000000        1.469000e+05
# 75%    628.250000       174650.000000        2.123500e+05
# max    933.000000       646500.000000        1.253500e+06
#
#        10-Yr Home Value Chg
# count            756.000000
# mean               0.244656
# std                0.179741
# min               -0.227025
# 25%                0.130049
# 50%                0.229761
# 75%                0.339882
# max                1.768235

# %%
# Preparing the Median Household Income dataframe.
medHHinc_10yr_df = medHHinc_df[["RegionID", "RegionName", "SizeRank", "2008-12", "2018-12"]]
medHHinc_10yr_df = medHHinc_10yr_df.set_index("RegionID")
medHHinc_10yr_df = medHHinc_10yr_df.rename(columns={"RegionName" : "Metro Name",
                                                    "SizeRank" : "Metro Rank",
                                                    "2008-12" : "2008-Q4 HH Income",
                                                    "2018-12" : "2018-Q4 HH Income"
                                                   })
medHHinc_10yr_df = medHHinc_10yr_df.dropna(how="any")

medHHinc_10yr_df["10-Yr HH Income Chg"] = (medHHinc_10yr_df.iloc[:,3] - medHHinc_10yr_df.iloc[:,2]) / \
                                           medHHinc_10yr_df.iloc[:,2]
medHHinc_10yr_df.describe()
# Out:
#        Metro Rank  2008-Q4 HH Income  2018-Q4 HH Income  10-Yr HH Income Chg
# count  382.000000         382.000000         382.000000           382.000000
# mean   198.356021       49149.669634       58548.409917             0.189399
# std    122.397824        8710.519263       11626.582128             0.076811
# min      0.000000       32621.170000       36791.517028            -0.041589
# 25%     95.250000       43348.640000       50808.717154             0.133489
# 50%    190.500000       47273.530000       55957.702839             0.187278
# 75%    292.750000       53441.380000       64299.238916             0.244895
# max    552.000000       87840.490000      124312.377637             0.439297

# %%
# Join both datasets
metro_10yr_df = pd.merge(medvalue_10yr_df, medHHinc_10yr_df, on="RegionID")
metro_10yr_df = metro_10yr_df.drop(columns=["Metro Name_y", 'Metro Rank_y'])
metro_10yr_df = metro_10yr_df.rename(columns={"Metro Name_x" : "Metro Name",
                                              "Metro Rank_x" : "Metro Rank"
                                             })
metro_10yr_df["2008-Q4 Home Value"] = metro_10yr_df["2008-Q4 Home Value"].map("${:,.0f}".format)
metro_10yr_df["2018-Q4 Home Value"] = metro_10yr_df["2018-Q4 Home Value"].map("${:,.0f}".format)
#metro_10yr_df["10-Yr Home Value Chg"] = (metro_10yr_df["10-Yr Home Value Chg"] * 100).map("{:,.1F}%".format)

metro_10yr_df["2008-Q4 HH Income"] = metro_10yr_df["2008-Q4 HH Income"].map("${:,.0f}".format)
metro_10yr_df["2018-Q4 HH Income"] = metro_10yr_df["2018-Q4 HH Income"].map("${:,.0f}".format)
#metro_10yr_df["10-Yr HH Income Chg"] = (metro_10yr_df["10-Yr HH Income Chg"] * 100).map("{:,.1F}%".format)

metro_10yr_df.head()
# Out:
#                                   Metro Name  Metro Rank 2008-Q4 Home Value  \
# RegionID
# 102001                         United States           0           $175,600
# 394913                          New York, NY           1           $394,500
# 753899    Los Angeles-Long Beach-Anaheim, CA           2           $444,600
# 394463                           Chicago, IL           3           $221,300
# 394514                 Dallas-Fort Worth, TX           4           $145,100
#
#          2018-Q4 Home Value  10-Yr Home Value Chg 2008-Q4 HH Income  \
# RegionID
# 102001             $223,900              0.275057           $52,177
# 394913             $437,300              0.108492           $67,115
# 753899             $650,200              0.462438           $59,422
# 394463             $224,200              0.013104           $60,396
# 394514             $240,200              0.655410           $57,718
#
#          2018-Q4 HH Income  10-Yr HH Income Chg
# RegionID
# 102001             $63,301             0.213208
# 394913             $79,370             0.182598
# 753899             $73,574             0.238176
# 394463             $71,481             0.183524
# 394514             $70,361             0.219052

# %%
value_chg = metro_10yr_df["10-Yr Home Value Chg"]
income_chg = metro_10yr_df["10-Yr HH Income Chg"]

plt.scatter(value_chg*100, income_chg*100, marker="o", facecolor="skyblue", edgecolor="grey",
            linewidth=0.75, zorder=2)
plt.xlabel("10-Year Chg in Med Home Value (%)")
plt.ylabel("10-Year Chg in Med HH Income (%)")
plt.title("10-Year Home Value vs. Income Appreciation")
plt.grid(zorder=1)
